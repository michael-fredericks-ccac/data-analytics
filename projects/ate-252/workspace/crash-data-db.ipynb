# %%
import sqlite3 as sql

# %%
dbconn = sql.connect('crash-data.db')

# %%
cursor = dbconn.cursor()

# %%
import pandas as pd

# %%
df = pandas.read_csv('Crash_Incident_Details_CY_1997_-_Current_Annual_County_Transportation.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-bb967a234765> in <module>
# ----> 1 df = pandas.read_csv('Crash_Incident_Details_CY_1997_-_Current_Annual_County_Transportation.csv')
#
# NameError: name 'pandas' is not defined

# %%
df = pd.read_csv('Crash_Incident_Details_CY_1997_-_Current_Annual_County_Transportation.csv', low_memory=True)
# Out:
# /home/michaelpfredericks/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (12,33,36,40) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Crash Record Number  County Code County Name  Municipality Code  \
# 0           2016000001           39      Lehigh              39301
# 1           2016000004            2   Allegheny               2301
# 2           2016000005           23    Delaware              23404
# 3           2016000007            2   Allegheny               2301
# 4           2016000008           39      Lehigh              39301
#
#       Municipality Name  District Code  District Name Police Agency Code  \
# 0        Allentown City              5   District 5-0              39301
# 1       Pittsburgh City             11  District 11-0              02301
# 2  Clifton Heights Boro              6   District 6-0              23404
# 3       Pittsburgh City             11  District 11-0              02301
# 4        Allentown City              5   District 5-0              39301
#
#      Police Agency Name  Crash Year  ...  Suspected Serious Injury  \
# ...

# %%
cursor.execute('''CREATE TABLE IF NOT EXISTS crashdata''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-14-bee8340e7e5b> in <module>
# ----> 1 cursor.execute('''CREATE TABLE IF NOT EXISTS crashdata''')
#
# OperationalError: incomplete input

# %%
df.to_sql(crash_data, dbconn, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-1d624a0ebd99> in <module>
# ----> 1 df.to_sql(crash_data, dbconn, if_exists='replace', index=False)
#
# NameError: name 'crash_data' is not defined

# %%
cursor.close()

# %%
dbconn.close()

# %%
df.head()
# Out:
#    Crash Record Number  County Code County Name  Municipality Code  \
# 0           2016000001           39      Lehigh              39301
# 1           2016000004            2   Allegheny               2301
# 2           2016000005           23    Delaware              23404
# 3           2016000007            2   Allegheny               2301
# 4           2016000008           39      Lehigh              39301
#
#       Municipality Name  District Code  District Name Police Agency Code  \
# 0        Allentown City              5   District 5-0              39301
# 1       Pittsburgh City             11  District 11-0              02301
# 2  Clifton Heights Boro              6   District 6-0              23404
# 3       Pittsburgh City             11  District 11-0              02301
# 4        Allentown City              5   District 5-0              39301
#
#      Police Agency Name  Crash Year  ...  Suspected Serious Injury  \
# ...

# %%
df.column()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-1d60d75b1e24> in <module>
# ----> 1 df.column()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
df.header()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-14774251d94e> in <module>
# ----> 1 df.header()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'header'

# %%
df.columns
# Out:
# Index(['Crash Record Number', 'County Code', 'County Name',
#        'Municipality Code', 'Municipality Name', 'District Code',
#        'District Name', 'Police Agency Code', 'Police Agency Name',
#        'Crash Year',
#        ...
#        'Suspected Serious Injury', 'Suspected Minor Injury', 'Possible Injury',
#        'Motorcycle Drinking Driver', 'Drug Related', 'Illegal Drug Related',
#        'School Bus Unit', 'Drugged Driver', 'Impaired Driver',
#        'Geographic Location of the Crash'],
#       dtype='object', length=180)

# %%
dtype_dict = dict(df.dtypes)
for i in df.columns:
    if dtype_dict[i] 
    data_type = str(dtype_dict[i])
    column_name = i.replace(' ', '-').lower() + ' ' + data_type
    columns.append(column_name)
columns
# Out:
# ['crash-record-number',
#  'county-code',
#  'county-name',
#  'municipality-code',
#  'municipality-name',
#  'district-code',
#  'district-name',
#  'police-agency-code',
#  'police-agency-name',
#  'crash-year',
#  'crash-month',
#  'day-of-week',
#  'time-of-day',
#  'hour-of-day',
#  'illumination',
#  'weather',
#  'road-condition',
#  'collision-type',
#  'work-zone-type',
#  'work-zone-location',
#  'intersection-type',
#  'traffic-control-device',
#  'location-type',
#  'urban-/-rural',
#  'fatality-count',
#  'injury-count',
#  'person-count',
#  'total-unit-count',
#  'school-bus-indicator',
#  'school-zone-indicator',
#  'latitude',
#  'longitude',
#  'arrival-time',
#  'dispatch-time',
#  'construction-zone-speed-limit',
#  'estimated-hours-closed',
#  'lane-closed',
#  'lane-closure-direction',
#  'notify-highway-maintenance',
#  'special-jurisdiction',
#  'traffic-control-device-function',
#  'traffic-detour',
#  'workers-present',
#  'work-zone-close/detour',
# ...

# %%
df[0].dtypes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-1a61859c957e> in <module>
# ----> 1 df[0].dtypes
#
# ...

# %%
df['Crash Data Record'].dtypes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Crash Data Record'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-45c12e0423fa> in <module>
# ...

# %%
dict(df.dtypes)
# Out:
# {'Crash Record Number': dtype('int64'),
#  'County Code': dtype('int64'),
#  'County Name': dtype('O'),
#  'Municipality Code': dtype('int64'),
#  'Municipality Name': dtype('O'),
#  'District Code': dtype('int64'),
#  'District Name': dtype('O'),
#  'Police Agency Code': dtype('O'),
#  'Police Agency Name': dtype('O'),
#  'Crash Year': dtype('int64'),
#  'Crash Month': dtype('int64'),
#  'Day of Week': dtype('float64'),
#  'Time of Day': dtype('O'),
#  'Hour of Day': dtype('float64'),
#  'Illumination': dtype('O'),
#  'Weather': dtype('O'),
#  'Road Condition': dtype('O'),
#  'Collision Type': dtype('O'),
#  'Work Zone Type': dtype('O'),
#  'Work Zone Location': dtype('O'),
#  'Intersection Type': dtype('O'),
#  'Traffic Control Device': dtype('O'),
#  'Location Type': dtype('O'),
#  'Urban / Rural': dtype('O'),
#  'Fatality Count': dtype('int64'),
#  'Injury Count': dtype('int64'),
#  'Person Count': dtype('int64'),
#  'Total Unit Count': dtype('int64'),
# ...
